# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Abdur rahim nishad\Downloads\ds_salaries.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.shape
# Out:
# (607, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
df.duplicated().sum()
# Out:
# 42

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df["work_year"].unique()
# Out:
# array([2020, 2021, 2022], dtype=int64)

# %%
del df["salary"]
# df.drop(["salary"],asis=1)

# %%
del df["salary_currency"]

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0          79833                 DE             0               DE
# 1         260000                 JP             0               JP
# 2         109024                 GB            50               GB
# 3          20000                 HN             0               HN
# 4         150000                 US            50               US
#
#   company_size
# 0            L
# 1            S
# 2            M
# 3            S
# 4            L

# %%
df=df.rename(columns={"salary_in_usd":"salary"})

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary employee_residence  remote_ratio company_location company_size
# 0   79833                 DE             0               DE            L
# 1  260000                 JP             0               JP            S
# 2  109024                 GB            50               GB            M
# 3   20000                 HN             0               HN            S
# 4  150000                 US            50               US            L

# %%
for i in ["work_year","experience_level","employment_type","job_title","employee_residence","remote_ratio","company_location","company_size"]:
    print(df[i].unique())
# Out:
# [2020 2021 2022]
# ['MI' 'SE' 'EN' 'EX']
# ['FT' 'CT' 'PT' 'FL']
# ['Data Scientist' 'Machine Learning Scientist' 'Big Data Engineer'
#  'Product Data Analyst' 'Machine Learning Engineer' 'Data Analyst'
#  'Lead Data Scientist' 'Business Data Analyst' 'Lead Data Engineer'
#  'Lead Data Analyst' 'Data Engineer' 'Data Science Consultant'
#  'BI Data Analyst' 'Director of Data Science' 'Research Scientist'
#  'Machine Learning Manager' 'Data Engineering Manager'
#  'Machine Learning Infrastructure Engineer' 'ML Engineer' 'AI Scientist'
#  'Computer Vision Engineer' 'Principal Data Scientist'
#  'Data Science Manager' 'Head of Data' '3D Computer Vision Researcher'
#  'Data Analytics Engineer' 'Applied Data Scientist'
#  'Marketing Data Analyst' 'Cloud Data Engineer' 'Financial Data Analyst'
#  'Computer Vision Software Engineer' 'Director of Data Engineering'
#  'Data Science Engineer' 'Principal Data Engineer'
#  'Machine Learning Developer' 'Applied Machine Learning Scientist'
# ...

# %%
one_hot=pd.get_dummies(df[["experience_level","employment_type","company_size"]],drop_first=True)

# %%
df=df.drop(["experience_level","employment_type","company_size"],axis=1)

# %%
df
# Out:
#      work_year                   job_title  salary employee_residence  \
# 0         2020              Data Scientist   79833                 DE
# 1         2020  Machine Learning Scientist  260000                 JP
# 2         2020           Big Data Engineer  109024                 GB
# 3         2020        Product Data Analyst   20000                 HN
# 4         2020   Machine Learning Engineer  150000                 US
# ..         ...                         ...     ...                ...
# 602       2022               Data Engineer  154000                 US
# 603       2022               Data Engineer  126000                 US
# 604       2022                Data Analyst  129000                 US
# 605       2022                Data Analyst  150000                 US
# 606       2022                AI Scientist  200000                 IN
#
#      remote_ratio company_location
# 0               0               DE
# 1               0               JP
# ...

# %%
new_df=pd.concat([df,one_hot],axis=1)

# %%
new_df.head()
# Out:
#    work_year                   job_title  salary employee_residence  \
# 0       2020              Data Scientist   79833                 DE
# 1       2020  Machine Learning Scientist  260000                 JP
# 2       2020           Big Data Engineer  109024                 GB
# 3       2020        Product Data Analyst   20000                 HN
# 4       2020   Machine Learning Engineer  150000                 US
#
#    remote_ratio company_location  experience_level_EX  experience_level_MI  \
# 0             0               DE                    0                    1
# 1             0               JP                    0                    0
# 2            50               GB                    0                    0
# 3             0               HN                    0                    1
# 4            50               US                    0                    0
#
#    experience_level_SE  employment_type_FL  employment_type_FT  \
# ...

# %%
one_hot
# Out:
#      experience_level_EX  experience_level_MI  experience_level_SE  \
# 0                      0                    1                    0
# 1                      0                    0                    1
# 2                      0                    0                    1
# 3                      0                    1                    0
# 4                      0                    0                    1
# ..                   ...                  ...                  ...
# 602                    0                    0                    1
# 603                    0                    0                    1
# 604                    0                    0                    1
# 605                    0                    0                    1
# 606                    0                    1                    0
#
#      employment_type_FL  employment_type_FT  employment_type_PT  \
# 0                     0                   1                   0
# ...

# %%
# df=pd.get_dummies(df,columns=["experience_level","employment_type","company_size"],drop_first=True)

# %%
# df.head()
# Out:
#    work_year                   job_title  salary employee_residence  \
# 0       2020              Data Scientist   79833                 DE
# 1       2020  Machine Learning Scientist  260000                 JP
# 2       2020           Big Data Engineer  109024                 GB
# 3       2020        Product Data Analyst   20000                 HN
# 4       2020   Machine Learning Engineer  150000                 US
#
#    remote_ratio company_location  experience_level_EX  experience_level_MI  \
# 0             0               DE                    0                    1
# 1             0               JP                    0                    0
# 2            50               GB                    0                    0
# 3             0               HN                    0                    1
# 4            50               US                    0                    0
#
#    experience_level_SE  employment_type_FL  employment_type_FT  \
# ...

# %%
df.describe()
# Out:
#          work_year         salary  remote_ratio
# count   607.000000     607.000000     607.00000
# mean   2021.405272  112297.869852      70.92257
# std       0.692133   70957.259411      40.70913
# min    2020.000000    2859.000000       0.00000
# 25%    2021.000000   62726.000000      50.00000
# 50%    2022.000000  101570.000000     100.00000
# 75%    2022.000000  150000.000000     100.00000
# max    2022.000000  600000.000000     100.00000

# %%
sns.histplot(df["salary"],kde=True)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
plt.hist(df["salary"])
# Out:
# (array([149., 228., 149.,  61.,  10.,   2.,   4.,   3.,   0.,   1.]),
#  array([  2859. ,  62573.1, 122287.2, 182001.3, 241715.4, 301429.5,
#         361143.6, 420857.7, 480571.8, 540285.9, 600000. ]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df["job_title"]=le.fit_transform(df["job_title"])
df["employee_residence"]=le.fit_transform(df["employee_residence"])
df["company_location"]=le.fit_transform(df["company_location"])

# %%
df.head()
# Out:
#    work_year  job_title  salary  employee_residence  remote_ratio  \
# 0       2020         22   79833                  14             0
# 1       2020         41  260000                  32             0
# 2       2020          7  109024                  20            50
# 3       2020         47   20000                  23             0
# 4       2020         38  150000                  55            50
#
#    company_location  experience_level_EX  experience_level_MI  \
# 0                12                    0                    1
# 1                29                    0                    0
# 2                18                    0                    0
# 3                20                    0                    1
# 4                48                    0                    0
#
#    experience_level_SE  employment_type_FL  employment_type_FT  \
# 0                    0                   0                   1
# 1                    1                   0                   1
# ...

# %%
df.dtypes
# Out:
# work_year              int64
# job_title              int32
# salary                 int64
# employee_residence     int32
# remote_ratio           int64
# company_location       int32
# experience_level_EX    uint8
# experience_level_MI    uint8
# experience_level_SE    uint8
# employment_type_FL     uint8
# employment_type_FT     uint8
# employment_type_PT     uint8
# company_size_M         uint8
# company_size_S         uint8
# dtype: object

# %%
x=df.drop(["salary"],axis=1)
x=df[["work_year"]]

# %%
x.head()
# Out:
#    work_year  job_title  employee_residence  remote_ratio  company_location  \
# 0       2020         22                  14             0                12
# 1       2020         41                  32             0                29
# 2       2020          7                  20            50                18
# 3       2020         47                  23             0                20
# 4       2020         38                  55            50                48
#
#    experience_level_EX  experience_level_MI  experience_level_SE  \
# 0                    0                    1                    0
# 1                    0                    0                    1
# 2                    0                    0                    1
# 3                    0                    1                    0
# 4                    0                    0                    1
#
#    employment_type_FL  employment_type_FT  employment_type_PT  company_size_M  \
# ...

# %%
y=df["salary"]

# %%
y.head()
# Out:
# 0     79833
# 1    260000
# 2    109024
# 3     20000
# 4    150000
# Name: salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=110)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(x_test)

# %%
sns.histplot(y_test-pred)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
model.score(x_test,y_test)
# Out:
# 0.36994835704117757

# %%
model.score(x_train,y_train)
# Out:
# 0.4124930055165067

# %%
plt.scatter(y_test,pred)
