# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.rand(1000),index=pd.date_range("2000-01-01",periods=1000),columns=["values"])

# %%
df.head()
# Out:
#               values
# 2000-01-01  0.365697
# 2000-01-02  0.076514
# 2000-01-03  0.446159
# 2000-01-04  0.394615
# 2000-01-05  0.279007

# %%
df.tail()
# Out:
#               values
# 2002-09-22  0.644688
# 2002-09-23  0.200535
# 2002-09-24  0.375598
# 2002-09-25  0.549837
# 2002-09-26  0.513154

# %%
df.head(30).plot(kind="hist",)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# plt.figure(figsize=(10,10))
# plt.figure(figsize=(16,9))
df.head(30).plot(kind="bar",figsize=(16,9))
# Out:
# <AxesSubplot:>

# %%
df.head(30).plot(kind="barh",figsize=(16,9))
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df["petal_width"].unique()
# Out:
# array([0.2, 0.4, 0.3, 0.1, 0.5, 0.6, 1.4, 1.5, 1.3, 1.6, 1. , 1.1, 1.8,
#        1.2, 1.7, 2.5, 1.9, 2.1, 2.2, 2. , 2.4, 2.3])

# %%
df.head(100).plot(figsize=(16,9))
# Out:
# <AxesSubplot:>

# %%
df.head(10).plot(kind="bar",figsize=(16,9))
plt.show()

# %%
plt.bar(df["sepal_width"],df["petal_length"],)
# Out:
# <BarContainer object of 150 artists>

# %%
sns.barplot(data=df,)
# Out:
# <AxesSubplot:>

# %%
df.drop("species",axis=1).iloc[0].plot(kind="bar",figsize=(15,9))
# Out:
# <AxesSubplot:>

# %%
# df.iloc[0]

# %%
df.drop("species",axis=1).iloc[3].plot(kind="bar",figsize=(15,9),color=["r","b","g"])
# Out:
# <AxesSubplot:>

# %%
df.drop("species",axis=1).iloc[3].plot.barh()
# Out:
# <AxesSubplot:>

# %%
df["sepal_length"].head(40).plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind="hist",figsize=(16,9),bins=100)
plt.show()

# %%
df.hist(figsize=(30,18),color="b",alpha=.60)
plt.show()

# %%
df.plot.scatter(x="sepal_length",y="sepal_width")
plt.show()

# %%
df.plot(kind="scatter",x="sepal_length",y="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.scatter(df['sepal_length'],df["sepal_width"],)
plt.show()

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
plt.scatter(df['petal_length'],df["petal_width"],)

# %%
pd.plotting.scatter_matrix(df,figsize=(20,15),)
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
df.drop("species",axis=1).iloc[0].plot(kind="pie",figsize=(17,10),autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df.drop("species",axis=1).head(5).T.plot(kind="pie",figsize=(20,20),autopct="%.2f",subplots=True)
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>, <AxesSubplot:ylabel='3'>,
#        <AxesSubplot:ylabel='4'>], dtype=object)

# %%
df.drop("species",axis=1).head(5).plot(kind="pie",figsize=(20,20),autopct="%.2f",subplots=True)
# Out:
# array([<AxesSubplot:ylabel='sepal_length'>,
#        <AxesSubplot:ylabel='sepal_width'>,
#        <AxesSubplot:ylabel='petal_length'>,
#        <AxesSubplot:ylabel='petal_width'>], dtype=object)
